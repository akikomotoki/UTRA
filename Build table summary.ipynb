# %%
import intake
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re

# Load CMIP6 via intake-esm
col_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(col_url)

# Search catalog
query = col.search(
    experiment_id="historical",
    table_id="SImon",
    variable_id=["siu", "siv", "siconc"],
    member_id="r1i1p1f1",
    grid_label="gn"
)

print(query.df.head())

# Convert query to dataset dictionary
dset_dict = query.to_dataset_dict(
    zarr_kwargs={'consolidated': True},
    xarray_combine_by_coords_kwargs={'compat': 'override'}
)
# Out:
#   activity_id institution_id     source_id experiment_id member_id table_id  \
# 0        CMIP      NOAA-GFDL      GFDL-CM4    historical  r1i1p1f1    SImon
# 1        CMIP      NOAA-GFDL      GFDL-CM4    historical  r1i1p1f1    SImon
# 2        CMIP      NOAA-GFDL      GFDL-CM4    historical  r1i1p1f1    SImon
# 3        CMIP           IPSL  IPSL-CM6A-LR    historical  r1i1p1f1    SImon
# 4        CMIP           IPSL  IPSL-CM6A-LR    historical  r1i1p1f1    SImon
#
#   variable_id grid_label                                             zstore  \
# 0         siu         gn  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...
# 1         siv         gn  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...
# 2      siconc         gn  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...
# 3      siconc         gn  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...
# 4         siu         gn  gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...
#
#    dcpp_init_year   version
# 0             NaN  20180701
# 1             NaN  20180701
# 2             NaN  20180701
# 3             NaN  20180803
# 4             NaN  20180803
#
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='43' class='' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [43/43 00:02&lt;00:00]
#     </div>

# %%
query['model_name'] = query.df.apply(
    lambda row: f"CMIP.{row['institution_id']}.{row['source_id']}.{row['experiment_id']}.{row['table_id']}.{row['grid_label']}",
    axis=1
)

model_names = query['model_name'].unique()

print("models in  query:")
for model_name in model_names:
    print(model_name)
# Out:
# models in  query:
# CMIP.NOAA-GFDL.GFDL-CM4.historical.SImon.gn
# CMIP.IPSL.IPSL-CM6A-LR.historical.SImon.gn
# CMIP.NASA-GISS.GISS-E2-1-G.historical.SImon.gn
# CMIP.BCC.BCC-CSM2-MR.historical.SImon.gn
# CMIP.BCC.BCC-ESM1.historical.SImon.gn
# CMIP.MIROC.MIROC6.historical.SImon.gn
# CMIP.AWI.AWI-CM-1-1-MR.historical.SImon.gn
# CMIP.NCAR.CESM2-WACCM.historical.SImon.gn
# CMIP.NCAR.CESM2.historical.SImon.gn
# CMIP.SNU.SAM0-UNICON.historical.SImon.gn
# CMIP.NASA-GISS.GISS-E2-1-H.historical.SImon.gn
# CMIP.CCCma.CanESM5.historical.SImon.gn
# CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.SImon.gn
# CMIP.NUIST.NESM3.historical.SImon.gn
# CMIP.CAMS.CAMS-CSM1-0.historical.SImon.gn
# CMIP.MPI-M.MPI-ESM1-2-LR.historical.SImon.gn
# CMIP.MPI-M.MPI-ESM1-2-HR.historical.SImon.gn
# CMIP.NOAA-GFDL.GFDL-ESM4.historical.SImon.gn
# CMIP.NCC.NorESM2-LM.historical.SImon.gn
# CMIP.MRI.MRI-ESM2-0.historical.SImon.gn
# CMIP.CAS.FGOALS-f3-L.historical.SImon.gn
# CMIP.NCC.NorESM2-MM.historical.SImon.gn
# CMIP.NCAR.CESM2-WACCM-FV2.historical.SImon.gn
# CMIP.NCAR.CESM2-FV2.historical.SImon.gn
# CMIP.FIO-QLNM.FIO-ESM-2-0.historical.SImon.gn
# CMIP.AWI.AWI-ESM-1-1-LR.historical.SImon.gn
# CMIP.THU.CIESM.historical.SImon.gn
# CMIP.CMCC.CMCC-CM2-SR5.historical.SImon.gn
# CMIP.EC-Earth-Consortium.EC-Earth3-AerChem.historical.SImon.gn
# CMIP.AS-RCEC.TaiESM1.historical.SImon.gn
# CMIP.NCC.NorCPM1.historical.SImon.gn
# CMIP.IPSL.IPSL-CM5A2-INCA.historical.SImon.gn
# CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.SImon.gn
# CMIP.CSIRO.ACCESS-ESM1-5.historical.SImon.gn
# CMIP.CMCC.CMCC-CM2-HR4.historical.SImon.gn
# CMIP.EC-Earth-Consortium.EC-Earth3.historical.SImon.gn
# CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.historical.SImon.gn
# CMIP.CAS.CAS-ESM2-0.historical.SImon.gn
# CMIP.CAS.FGOALS-g3.historical.SImon.gn
# CMIP.EC-Earth-Consortium.EC-Earth3-CC.historical.SImon.gn
# CMIP.CMCC.CMCC-ESM2.historical.SImon.gn
# CMIP.MPI-M.ICON-ESM-LR.historical.SImon.gn
# CMIP.IPSL.IPSL-CM6A-LR-INCA.historical.SImon.gn

# %%
model = 'CMIP.CAS.CAS-ESM2-0.historical.SImon.gn'
ds = dset_dict[model]

ds.attrs
# Out:
# {'Conventions': 'CF-1.7 CMIP-6.2',
#  'activity_id': 'CMIP',
#  'branch_method': 'Spin-up documentation',
#  'branch_time_in_child': 674885.0,
#  'branch_time_in_parent': 36135.0,
#  'cmor_version': '3.5.0',
#  'contact': 'He Zhang(zhanghe@mail.iap.ac.cn)',
#  'data_specs_version': '01.00.31',
#  'experiment': 'all-forcing simulation of the recent past',
#  'experiment_id': 'historical',
#  'external_variables': 'areacello',
#  'forcing_index': 1,
#  'frequency': 'mon',
#  'further_info_url': 'https://furtherinfo.es-doc.org/CMIP6.CAS.CAS-ESM2-0.historical.none.r1i1p1f1',
#  'grid': 'gs1x1',
#  'grid_label': 'gn',
#  'history': '2020-12-25T11:51:49Z ;rewrote data to be consistent with CMIP for variable siage found in table SImon.',
#  'initialization_index': 1,
#  'institution': 'Chinese Academy of Sciences, Beijing 100029, China',
#  'institution_id': 'CAS',
#  'license': 'CMIP6 model data produced by Chinese Academy of Sciences (CAS) is licensed under a Creative Commons Attribution ShareAlike 4.0 International License (https://creativecommons.org/licenses). Consult https://pcmdi.llnl.gov/CMIP6/TermsOfUse for terms of use governing CMIP6 output, including citation requirements and proper acknowledgment. Further information about this data, including some limitations, can be found via the further_info_url (recorded as a global attribute in this file). The data producers and data providers make no warranty, either express or implied, including, but not limited to, warranties of merchantability and fitness for a particular purpose. All liabilities arising from the supply of the information (including any liability arising in negligence) are excluded to the fullest extent permitted by law.',
#  'mip_era': 'CMIP6',
#  'nominal_resolution': '100 km',
#  'parent_activity_id': 'CMIP',
#  'parent_experiment_id': 'piControl',
#  'parent_mip_era': 'CMIP6',
#  'parent_source_id': 'CAS-ESM2-0',
#  'parent_time_units': 'days since 0001-01-01',
#  'parent_variant_label': 'r1i1p1f1',
#  'physics_index': 1,
#  'product': 'model-output',
#  'realization_index': 1,
#  'realm': 'seaIce',
#  'references': 'Zhang, H. and coauthors, 2020: CAS-ESM2: Description and climate simulation performance of the Chinese Academy of Sciences (CAS) Earth System Model (ESM) version 2. JAMES,12, e2020MS002210. https://doi.org/10.1029/2020MS002210.',
#  'run_variant': 'forcing: black carbon aerosol only',
#  'source': 'CAS-ESM 2.0 (2019): \naerosol: IAP AACM\natmos: IAP AGCM 5.0 (Finite difference dynamical core; 256 x 128 longitude/latitude; 35 levels; top level 2.2 hPa)\natmosChem: IAP AACM\nland: CoLM\nlandIce: none\nocean: LICOM2.0 (LICOM2.0, primarily 1deg; 362 x 196 longitude/latitude; 30 levels; top grid cell 0-10 m)\nocnBgchem: IAP OBGCM\nseaIce: CICE4',
#  'source_id': 'CAS-ESM2-0',
#  'source_type': 'AOGCM',
#  'sub_experiment': 'none',
#  'sub_experiment_id': 'none',
#  'table_id': 'SImon',
#  'table_info': 'Creation Date:(07 October 2019) MD5:b9834a2d0728c0da123535a4e4240b5b',
#  'title': 'CAS-ESM2-0 output prepared for CMIP6',
#  'variant_label': 'r1i1p1f1',
#  'version_id': 'v20201225',
#  'intake_esm_attrs:activity_id': 'CMIP',
#  'intake_esm_attrs:institution_id': 'CAS',
#  'intake_esm_attrs:source_id': 'CAS-ESM2-0',
#  'intake_esm_attrs:experiment_id': 'historical',
#  'intake_esm_attrs:member_id': 'r1i1p1f1',
#  'intake_esm_attrs:table_id': 'SImon',
#  'intake_esm_attrs:grid_label': 'gn',
#  'intake_esm_attrs:version': '20201225',
#  'intake_esm_attrs:_data_format_': 'zarr',
#  'intake_esm_dataset_key': 'CMIP.CAS.CAS-ESM2-0.historical.SImon.gn'}

# %%
# Initialize list to collect metadata for each model
metadata = []

# Function to extract ocean and atm models
def extract_ocean_model(source_attr):
    match = re.search(r"ocean:\s*([A-Za-z0-9.]+)", source_attr)
    return match.group(1) if match else "N/A"

def extract_atmosphere_model(source_attr):
    match = re.search(r"atmos:\s*([A-Za-z0-9. ]+)", source_attr)
    return match.group(1).strip() if match else "N/A"


# Loop through each model in dataset dictionary
for ds_name, ds in dset_dict.items():
    print(f"Dataset: {ds_name}")
    print(ds.data_vars)
    
    # Retrieve attributes for metadata table
    institution = ds.attrs.get('institution', 'N/A')
    resolution = ds.attrs.get('nominal_resolution', 'N/A')
    grid_type = ds.attrs.get('grid_label', 'N/A')
    num_ensembles = len(ds.member_id) if 'member_id' in ds.coords else 'N/A'
    rheology_scheme = ds.attrs.get('rheology_scheme', 'N/A')
    atmosphere_model = ds.attrs.get('atmosphere', 'N/A')
    references = ds.attrs.get('references', 'N/A')
    
    # source attr
    source_attr = ds.attrs.get('source', 'N/A')
    ocean_model = extract_ocean_model(source_attr)
    atmosphere_model = extract_atmosphere_model(source_attr)
    
    metadata.append([
        ds_name, institution, resolution, grid_type, num_ensembles, 
        rheology_scheme, atmosphere_model, ocean_model, references
    ])

# Convert metadata list to DataFrame
metadata_table = pd.DataFrame(metadata, columns=[
    'Model', 'Institution', 'Resolution', 'Grid Type', 
    'Number of Ensembles', 'Rheology Scheme', 
    'Atmosphere Model', 'Ocean Model', 'References'
])

# Save the metadata table to a CSV file
# metadata_table.to_csv('metadata.csv', index=False)

# Display the metadata table
print(metadata_table)
# Out:
# Dataset: CMIP.IPSL.IPSL-CM6A-LR.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 600, 332, 362), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 845, 332, 362), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 833, 332, 362), meta=np.ndarray>
# Dataset: CMIP.NCAR.CESM2-FV2.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 705, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 912, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 898, 384, 320), meta=np.ndarray>
# Dataset: CMIP.EC-Earth-Consortium.EC-Earth3-CC.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 262, 292, 362), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 270, 292, 362), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 267, 292, 362), meta=np.ndarray>
# Dataset: CMIP.EC-Earth-Consortium.EC-Earth3.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 253, 292, 362), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 260, 292, 362), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 257, 292, 362), meta=np.ndarray>
# Dataset: CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 254, 292, 362), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 261, 292, 362), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 257, 292, 362), meta=np.ndarray>
# Dataset: CMIP.MPI-M.MPI-ESM1-2-HR.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 175, 404, 802), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 192, 404, 802), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 192, 404, 802), meta=np.ndarray>
# Dataset: CMIP.SNU.SAM0-UNICON.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 600, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 611, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 609, 384, 320), meta=np.ndarray>
# Dataset: CMIP.CMCC.CMCC-CM2-SR5.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 746, 291, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 919, 291, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 908, 291, 360), meta=np.ndarray>
# Dataset: CMIP.NCAR.CESM2-WACCM-FV2.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 710, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 90, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 905, 384, 320), meta=np.ndarray>
# Dataset: CMIP.CMCC.CMCC-CM2-HR4.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 52, 1050, 1440), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 49, 1050, 1440), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 48, 1050, 1440), meta=np.ndarray>
# Dataset: CMIP.NASA-GISS.GISS-E2-1-G.historical.SImon.gn
# Data variables:
#     siu      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 963, 90, 144), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 963, 90, 144), meta=np.ndarray>
# Dataset: CMIP.MPI-M.ICON-ESM-LR.historical.SImon.gn
# Data variables:
#     siconc              (member_id, dcpp_init_year, time, i) float32 dask.array<chunksize=(1, 1, 311, 235403), meta=np.ndarray>
#     vertices_latitude   (i, vertices) float64 dask.array<chunksize=(235403, 3), meta=np.ndarray>
#     vertices_longitude  (i, vertices) float64 dask.array<chunksize=(235403, 3), meta=np.ndarray>
# Dataset: CMIP.CSIRO.ACCESS-ESM1-5.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 596, 300, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 740, 300, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 738, 300, 360), meta=np.ndarray>
# Dataset: CMIP.CAS.FGOALS-f3-L.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 152, 218, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 152, 218, 360), meta=np.ndarray>
# Dataset: CMIP.CAMS.CAMS-CSM1-0.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 600, 200, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 172, 200, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 172, 200, 360), meta=np.ndarray>
# Dataset: CMIP.CCCma.CanESM5.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 600, 291, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 736, 291, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 731, 291, 360), meta=np.ndarray>
# Dataset: CMIP.CAS.FGOALS-g3.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 158, 218, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 158, 218, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 158, 218, 360), meta=np.ndarray>
# Dataset: CMIP.NCAR.CESM2.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 600, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 949, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 934, 384, 320), meta=np.ndarray>
# Dataset: CMIP.MRI.MRI-ESM2-0.historical.SImon.gn
# Data variables:
#     siconc              (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 600, 363, 360), meta=np.ndarray>
#     vertices_latitude   (y, x, vertices) float64 dask.array<chunksize=(363, 360, 4), meta=np.ndarray>
#     vertices_longitude  (y, x, vertices) float64 dask.array<chunksize=(363, 360, 4), meta=np.ndarray>
# Dataset: CMIP.MIROC.MIROC6.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 600, 256, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 990, 256, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 990, 256, 360), meta=np.ndarray>
# Dataset: CMIP.NCC.NorCPM1.historical.SImon.gn
# Data variables:
#     siconc              (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 674, 384, 320), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
# Dataset: CMIP.AWI.AWI-CM-1-1-MR.historical.SImon.gn
# Data variables:
#     siu      (member_id, dcpp_init_year, time, ncells) float32 dask.array<chunksize=(1, 1, 3, 830305), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, ncells) float32 dask.array<chunksize=(1, 1, 3, 830305), meta=np.ndarray>
# Dataset: CMIP.NCC.NorESM2-LM.historical.SImon.gn
# Data variables:
#     siconc              (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 509, 384, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(384, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(384, 360, 4), meta=np.ndarray>
# Dataset: CMIP.THU.CIESM.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 100, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 100, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 100, 384, 320), meta=np.ndarray>
# Dataset: CMIP.BCC.BCC-CSM2-MR.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 149, 232, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 149, 232, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 149, 232, 360), meta=np.ndarray>
# Dataset: CMIP.BCC.BCC-ESM1.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 149, 232, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 149, 232, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 149, 232, 360), meta=np.ndarray>
# Dataset: CMIP.NOAA-GFDL.GFDL-CM4.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 60, 1080, 1440), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 42, 1080, 1440), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 41, 1080, 1440), meta=np.ndarray>
# Dataset: CMIP.IPSL.IPSL-CM5A2-INCA.historical.SImon.gn
# Data variables:
#     area     (y, x) float32 dask.array<chunksize=(149, 182), meta=np.ndarray>
#     siconc   (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 990, 149, 182), meta=np.ndarray>
# Dataset: CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 220, 256), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 220, 256), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 220, 256), meta=np.ndarray>
# Dataset: CMIP.EC-Earth-Consortium.EC-Earth3-AerChem.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 258, 292, 362), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 266, 292, 362), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 263, 292, 362), meta=np.ndarray>
# Dataset: CMIP.NCAR.CESM2-WACCM.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 600, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 930, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 915, 384, 320), meta=np.ndarray>
# Dataset: CMIP.AWI.AWI-ESM-1-1-LR.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, ncells) float32 dask.array<chunksize=(1, 1, 23, 126859), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, ncells) float32 dask.array<chunksize=(1, 1, 21, 126859), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, ncells) float32 dask.array<chunksize=(1, 1, 21, 126859), meta=np.ndarray>
# Dataset: CMIP.CAS.CAS-ESM2-0.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 196, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 196, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 196, 360), meta=np.ndarray>
# Dataset: CMIP.IPSL.IPSL-CM6A-LR-INCA.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 705, 332, 362), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 812, 332, 362), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 800, 332, 362), meta=np.ndarray>
# Dataset: CMIP.CMCC.CMCC-ESM2.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 740, 291, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 907, 291, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, i, j) float32 dask.array<chunksize=(1, 1, 896, 291, 360), meta=np.ndarray>
# Dataset: CMIP.NOAA-GFDL.GFDL-ESM4.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 160, 576, 720), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 149, 576, 720), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, y, x) float32 dask.array<chunksize=(1, 1, 147, 576, 720), meta=np.ndarray>
# Dataset: CMIP.NASA-GISS.GISS-E2-1-H.historical.SImon.gn
# Data variables:
#     siu      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 963, 90, 144), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, lat, lon) float32 dask.array<chunksize=(1, 1, 963, 90, 144), meta=np.ndarray>
# Dataset: CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 668, 300, 360), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 782, 300, 360), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 781, 300, 360), meta=np.ndarray>
# Dataset: CMIP.NCC.NorESM2-MM.historical.SImon.gn
# Data variables:
#     siconc              (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 501, 384, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(384, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(384, 360, 4), meta=np.ndarray>
# Dataset: CMIP.AS-RCEC.TaiESM1.historical.SImon.gn
# Data variables:
#     siconc              (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 738, 384, 320), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(384, 320, 4), meta=np.ndarray>
# Dataset: CMIP.FIO-QLNM.FIO-ESM-2-0.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 747, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 789, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 787, 384, 320), meta=np.ndarray>
# Dataset: CMIP.NUIST.NESM3.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 1366, 384, 320), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 848, 384, 320), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, nj, ni) float32 dask.array<chunksize=(1, 1, 848, 384, 320), meta=np.ndarray>
# Dataset: CMIP.MPI-M.MPI-ESM1-2-LR.historical.SImon.gn
# Data variables:
#     siconc   (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 967, 220, 256), meta=np.ndarray>
#     siu      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 220, 256), meta=np.ndarray>
#     siv      (member_id, dcpp_init_year, time, j, i) float32 dask.array<chunksize=(1, 1, 990, 220, 256), meta=np.ndarray>
#                                                 Model  \
# 0          CMIP.IPSL.IPSL-CM6A-LR.historical.SImon.gn
# 1             CMIP.NCAR.CESM2-FV2.historical.SImon.gn
# 2   CMIP.EC-Earth-Consortium.EC-Earth3-CC.historic...
# 3   CMIP.EC-Earth-Consortium.EC-Earth3.historical....
# 4   CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.hist...
# 5        CMIP.MPI-M.MPI-ESM1-2-HR.historical.SImon.gn
# 6            CMIP.SNU.SAM0-UNICON.historical.SImon.gn
# 7          CMIP.CMCC.CMCC-CM2-SR5.historical.SImon.gn
# 8       CMIP.NCAR.CESM2-WACCM-FV2.historical.SImon.gn
# 9          CMIP.CMCC.CMCC-CM2-HR4.historical.SImon.gn
# 10     CMIP.NASA-GISS.GISS-E2-1-G.historical.SImon.gn
# 11         CMIP.MPI-M.ICON-ESM-LR.historical.SImon.gn
# 12       CMIP.CSIRO.ACCESS-ESM1-5.historical.SImon.gn
# 13           CMIP.CAS.FGOALS-f3-L.historical.SImon.gn
# 14          CMIP.CAMS.CAMS-CSM1-0.historical.SImon.gn
# 15             CMIP.CCCma.CanESM5.historical.SImon.gn
# 16             CMIP.CAS.FGOALS-g3.historical.SImon.gn
# 17                CMIP.NCAR.CESM2.historical.SImon.gn
# 18            CMIP.MRI.MRI-ESM2-0.historical.SImon.gn
# 19              CMIP.MIROC.MIROC6.historical.SImon.gn
# 20               CMIP.NCC.NorCPM1.historical.SImon.gn
# 21         CMIP.AWI.AWI-CM-1-1-MR.historical.SImon.gn
# 22            CMIP.NCC.NorESM2-LM.historical.SImon.gn
# 23                 CMIP.THU.CIESM.historical.SImon.gn
# 24           CMIP.BCC.BCC-CSM2-MR.historical.SImon.gn
# 25              CMIP.BCC.BCC-ESM1.historical.SImon.gn
# 26        CMIP.NOAA-GFDL.GFDL-CM4.historical.SImon.gn
# 27      CMIP.IPSL.IPSL-CM5A2-INCA.historical.SImon.gn
# 28  CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.histori...
# 29  CMIP.EC-Earth-Consortium.EC-Earth3-AerChem.his...
# 30          CMIP.NCAR.CESM2-WACCM.historical.SImon.gn
# 31        CMIP.AWI.AWI-ESM-1-1-LR.historical.SImon.gn
# 32            CMIP.CAS.CAS-ESM2-0.historical.SImon.gn
# 33    CMIP.IPSL.IPSL-CM6A-LR-INCA.historical.SImon.gn
# 34            CMIP.CMCC.CMCC-ESM2.historical.SImon.gn
# 35       CMIP.NOAA-GFDL.GFDL-ESM4.historical.SImon.gn
# 36     CMIP.NASA-GISS.GISS-E2-1-H.historical.SImon.gn
# 37   CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.SImon.gn
# 38            CMIP.NCC.NorESM2-MM.historical.SImon.gn
# 39           CMIP.AS-RCEC.TaiESM1.historical.SImon.gn
# 40      CMIP.FIO-QLNM.FIO-ESM-2-0.historical.SImon.gn
# 41               CMIP.NUIST.NESM3.historical.SImon.gn
# 42       CMIP.MPI-M.MPI-ESM1-2-LR.historical.SImon.gn
#
#                                           Institution Resolution Grid Type  \
# 0   Institut Pierre Simon Laplace, Paris 75252, Fr...     100 km        gn
# 1   National Center for Atmospheric Research, Clim...     250 km        gn
# 2   AEMET, Spain; BSC, Spain; CNR-ISAC, Italy; DMI...     100 km        gn
# 3   AEMET, Spain; BSC, Spain; CNR-ISAC, Italy; DMI...     100 km        gn
# 4   AEMET, Spain; BSC, Spain; CNR-ISAC, Italy; DMI...     100 km        gn
# 5   Max Planck Institute for Meteorology, Hamburg ...      50 km        gn
# 6   Seoul National University, Seoul 08826, Republ...     100 km        gn
# 7   Fondazione Centro Euro-Mediterraneo sui Cambia...     100 km        gn
# 8   National Center for Atmospheric Research, Clim...     100 km        gn
# 9   Fondazione Centro Euro-Mediterraneo sui Cambia...      25 km        gn
# 10  Goddard Institute for Space Studies, New York,...     250 km        gn
# 11  Max Planck Institute for Meteorology, Hamburg ...      50 km        gn
# 12  Commonwealth Scientific and Industrial Researc...     250 km        gn
# 13  Chinese Academy of Sciences, Beijing 100029, C...     100 km        gn
# 14  Chinese Academy of Meteorological Sciences, Be...     100 km        gn
# 15  Canadian Centre for Climate Modelling and Anal...     100 km        gn
# 16  Chinese Academy of Sciences, Beijing 100029, C...     100 km        gn
# 17  National Center for Atmospheric Research, Clim...     100 km        gn
# 18  Meteorological Research Institute, Tsukuba, Ib...     100 km        gn
# 19  JAMSTEC (Japan Agency for Marine-Earth Science...     100 km        gn
# 20  NorESM Climate modeling Consortium consisting ...     100 km        gn
# 21  Alfred Wegener Institute, Helmholtz Centre for...      25 km        gn
# 22  NorESM Climate modeling Consortium consisting ...     100 km        gn
# 23  Department of Earth System Science, Tsinghua U...     100 km        gn
# 24      Beijing Climate Center, Beijing 100081, China     100 km        gn
# 25      Beijing Climate Center, Beijing 100081, China     100 km        gn
# 26  National Oceanic and Atmospheric Administratio...      25 km        gn
# 27  Institut Pierre Simon Laplace, Paris 75252, Fr...     250 km        gn
# 28  ETH Zurich, Switzerland; Max Planck Institut f...     250 km        gn
# 29  AEMET, Spain; BSC, Spain; CNR-ISAC, Italy; DMI...     100 km        gn
# 30  National Center for Atmospheric Research, Clim...     100 km        gn
# 31  Alfred Wegener Institute, Helmholtz Centre for...      50 km        gn
# 32  Chinese Academy of Sciences, Beijing 100029, C...     100 km        gn
# 33  Institut Pierre Simon Laplace, Paris 75252, Fr...     100 km        gn
# 34  Fondazione Centro Euro-Mediterraneo sui Cambia...     100 km        gn
# 35  National Oceanic and Atmospheric Administratio...      50 km        gn
# 36  Goddard Institute for Space Studies, New York,...     250 km        gn
# 37  CSIRO (Commonwealth Scientific and Industrial ...     250 km        gn
# 38  NorESM Climate modeling Consortium consisting ...     100 km        gn
# 39  Research Center for Environmental Changes, Aca...     100 km        gn
# 40  FIO (First Institute of Oceanography, State Oc...     100 km        gn
# 41  Nanjing University of Information Science and ...     100 km        gn
# 42  Max Planck Institute for Meteorology, Hamburg ...     250 km        gn
#
#     Number of Ensembles Rheology Scheme    Atmosphere Model Ocean Model  \
# 0                     1             N/A                LMDZ        NEMO
# 1                     1             N/A                 N/A        POP2
# 2                     1             N/A          IFS cy36r4     NEMO3.6
# 3                     1             N/A          IFS cy36r4     NEMO3.6
# 4                     1             N/A          IFS cy36r4     NEMO3.6
# 5                     1             N/A            ECHAM6.3   MPIOM1.63
# 6                     1             N/A  CAM5.3 with UNICON        POP2
# 7                     1             N/A              CAM5.3     NEMO3.6
# 8                     1             N/A                 N/A        POP2
# 9                     1             N/A                CAM4     NEMO3.6
# 10                    1             N/A                GISS        GISS
# 11                    1             N/A                ICON        ICON
# 12                    1             N/A             HadGAM2      ACCESS
# 13                    1             N/A            FAMIL2.2    LICOM3.0
# 14                    1             N/A              ECHAM5        MOM4
# 15                    1             N/A              CanAM5   NEMO3.4.1
# 16                    1             N/A            GAMIL3.0    LICOM3.0
# 17                    1             N/A                 N/A        POP2
# 18                    1             N/A                 MRI  MRI.COM4.4
# 19                    1             N/A           CCSR AGCM     COCO4.9
# 20                    1             N/A                 CAM    MICOM1.1
# 21                    1             N/A                 N/A         N/A
# 22                    1             N/A                 CAM       MICOM
# 23                    1             N/A               CIESM       CIESM
# 24                    1             N/A                 BCC        MOM4
# 25                    1             N/A                 BCC        MOM4
# 26                    1             N/A                GFDL        GFDL
# 27                    1             N/A                LMDZ        NEMO
# 28                    1             N/A            ECHAM6.3   MPIOM1.63
# 29                    1             N/A          IFS cy36r4     NEMO3.6
# 30                    1             N/A                 N/A        POP2
# 31                    1             N/A                 N/A         N/A
# 32                    1             N/A        IAP AGCM 5.0    LICOM2.0
# 33                    1             N/A                LMDZ        NEMO
# 34                    1             N/A              CAM5.3     NEMO3.6
# 35                    1             N/A                GFDL        GFDL
# 36                    1             N/A                GISS       HYCOM
# 37                    1             N/A               MetUM      ACCESS
# 38                    1             N/A                 CAM       MICOM
# 39                    1             N/A              TaiAM1        POP2
# 40                    1             N/A                CAM4        POP2
# 41                    1             N/A          ECHAM v6.3        NEMO
# 42                    1             N/A            ECHAM6.3   MPIOM1.63
#
#                                            References
# 0                                                 N/A
# 1                                                 N/A
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# 5   MPI-ESM: Mauritsen, T. et al. (2019), Developm...
# 6   Park et al. (2019) : Global Climate Simulated ...
# 7                                                none
# 8                                                 N/A
# 9                                                none
# 10            https://data.giss.nasa.gov/modelE/cmip6
# 11  Giorgetta, M. A. et al. (2018). ICON‐A, the at...
# 12                                                N/A
# 13  Model described by He Bian et al.,Bao Qing et al.
# 14  Model described by Rong et al (J. Meteoro. Res...
# 15  Geophysical Model Development Special issue on...
# 16                                                N/A
# 17                                                N/A
# 18                                                N/A
# 19                                                N/A
# 20  Bethke et al. (in prep), NorCPM1 and its contr...
# 21                                                N/A
# 22                                                N/A
# 23                                                N/A
# 24  Model described by Tongwen Wu et al. (JGR 2013...
# 25  Model described by Tongwen Wu et al. (JGR 2013...
# 26                     see further_info_url attribute
# 27                                                N/A
# 28  MPI-ESM1.2-HAM: Mauritsen, T. et al. (2019), D...
# 29                                                N/A
# 30                                                N/A
# 31                                                N/A
# 32  Zhang, H. and coauthors, 2020: CAS-ESM2: Descr...
# 33                                                N/A
# 34                                               none
# 35                     see further_info_url attribute
# 36            https://data.giss.nasa.gov/modelE/cmip6
# 37                                                N/A
# 38                                                N/A
# 39                               10.5194/gmd-2019-377
# 40                                                N/A
# 41  Model described by Cao et al. 2018 GMD   Also ...
# 42  MPI-ESM: Mauritsen, T. et al. (2019), Developm...

# %%
metadata_table.head(9)
metadata_table.tail()
metadata_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Model                43 non-null     object
#  1   Institution          43 non-null     object
#  2   Resolution           43 non-null     object
#  3   Grid Type            43 non-null     object
#  4   Number of Ensembles  43 non-null     int64
#  5   Rheology Scheme      43 non-null     object
#  6   Atmosphere Model     43 non-null     object
#  7   Ocean Model          43 non-null     object
#  8   References           43 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 3.1+ KB

# %%
metadata_table.groupby("Atmosphere Model").count()

# groupby can take any column name or take a ist of column names if you specify it. 
# alternative to count could be median, mean, std(), variance etc. 
# could also apply and give fctn
# Out:
#                     Model  Institution  Resolution  Grid Type  \
# Atmosphere Model
# BCC                     2            2           2          2
# CAM                     3            3           3          3
# CAM4                    2            2           2          2
# CAM5.3                  2            2           2          2
# CAM5.3 with UNICON      1            1           1          1
# CCSR AGCM               1            1           1          1
# CIESM                   1            1           1          1
# CanAM5                  1            1           1          1
# ECHAM v6.3              1            1           1          1
# ECHAM5                  1            1           1          1
# ECHAM6.3                3            3           3          3
# FAMIL2.2                1            1           1          1
# GAMIL3.0                1            1           1          1
# GFDL                    2            2           2          2
# GISS                    2            2           2          2
# HadGAM2                 1            1           1          1
# IAP AGCM 5.0            1            1           1          1
# ICON                    1            1           1          1
# IFS cy36r4              4            4           4          4
# LMDZ                    3            3           3          3
# MRI                     1            1           1          1
# MetUM                   1            1           1          1
# N/A                     6            6           6          6
# TaiAM1                  1            1           1          1
#
#                     Number of Ensembles  Rheology Scheme  Ocean Model  \
# Atmosphere Model
# BCC                                   2                2            2
# CAM                                   3                3            3
# CAM4                                  2                2            2
# CAM5.3                                2                2            2
# CAM5.3 with UNICON                    1                1            1
# CCSR AGCM                             1                1            1
# CIESM                                 1                1            1
# CanAM5                                1                1            1
# ECHAM v6.3                            1                1            1
# ECHAM5                                1                1            1
# ECHAM6.3                              3                3            3
# FAMIL2.2                              1                1            1
# GAMIL3.0                              1                1            1
# GFDL                                  2                2            2
# GISS                                  2                2            2
# HadGAM2                               1                1            1
# IAP AGCM 5.0                          1                1            1
# ICON                                  1                1            1
# IFS cy36r4                            4                4            4
# LMDZ                                  3                3            3
# MRI                                   1                1            1
# MetUM                                 1                1            1
# N/A                                   6                6            6
# TaiAM1                                1                1            1
#
#                     References
# Atmosphere Model
# BCC                          2
# CAM                          3
# CAM4                         2
# CAM5.3                       2
# CAM5.3 with UNICON           1
# CCSR AGCM                    1
# CIESM                        1
# CanAM5                       1
# ECHAM v6.3                   1
# ECHAM5                       1
# ECHAM6.3                     3
# FAMIL2.2                     1
# GAMIL3.0                     1
# GFDL                         2
# GISS                         2
# HadGAM2                      1
# IAP AGCM 5.0                 1
# ICON                         1
# IFS cy36r4                   4
# LMDZ                         3
# MRI                          1
# MetUM                        1
# N/A                          6
# TaiAM1                       1
